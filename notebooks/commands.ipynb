# %% [markdown]
# useful commands

# %%
# Thomas commands - branch mreye

# install the packages
python -m pip install -e .

# test
qc_list_bids_csv /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/test_fetalqc --mask-patterns-base /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/test_fetalqc/derivatives/masks/ --mask-patterns "sub-{subject}_mask.nii.gz" --suffix T1w --out-csv /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/test_fetalqc/bids_csv.csv
qc_generate_reports /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/test_fetalqc /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/test_fetalqc/bids_csv.csv
qc_generate_index /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/test_fetalqc

# mine
qc_list_bids_csv /mnt/sda1/Repos/a-eye/Output/mri_qc/samples/samples_v3_bids --mask-patterns-base /mnt/sda1/Repos/a-eye/Output/mri_qc/samples/samples_v3_bids/derivatives/masks/ --mask-patterns "sub-{subject}_mask.nii.gz" --suffix T1w --out-csv /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/eye_qc_83/bids_csv.csv
qc_generate_reports /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/fetalqc_non-labeled-dataset /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/fetalqc_non-labeled-dataset/bids_csv.csv
qc_generate_index /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/eye_qc_100

# pipeline
qc_run_pipeline --bids_dir /home/jaimebarranco/Desktop/samples_v3_bids --out_path /home/jaimebarranco/Desktop/fetal_qc_output/ --mask-patterns-base /home/jaimebarranco/Desktop/samples_v3_bids/derivatives/masks/ --mask-patterns "sub-{subject}_mask.nii.gz" --suffix T1w

# %% [markdown]
# ratings to csv

# %%
# if there are subjects not rated, it will not work
python fetal_brain_qc/cli/ratings_to_csv.py -h
python fetal_brain_qc/cli/ratings_to_csv.py /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/eye_qc_83/2_ratings/2_remaining_68/bene /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/eye_qc_83/1_reports/2_remaining_68/bids_csv.csv --out_csv /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/eye_qc_83/2_ratings/2_remaining_68/bene/ratings.csv
# test
python fetal_brain_qc/cli/ratings_to_csv.py /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/test_fetalqc/ratings/ /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/test_fetalqc/bids_csv.csv --out_csv /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/test_fetalqc/ratings.csv

python fetal_brain_qc/cli/ratings_to_csv.py /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/eye_qc_83/2_ratings/1_training_session/cyril /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/eye_qc_83/1_reports/1_training_session/bids_csv.csv --out_csv /mnt/sda1/Repos/a-eye/Output/mri_qc/fetal/eye_qc_83/2_ratings/1_training_session/cyril/ratings.csv
